# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
#import mglearn

# %%
# 1. Load
# Assuming your data is in a Excel file with columns 'x' and 'y'

data = pd.read_csv("cold_cases.csv")
data.head()
# Out:
#    Year  Winter Cases  Summer Cases  Autumn Cases
# 0  1994        991710        520360        796901
# 1  1995       1160236        434682        767206
# 2  1996        943131        530671        773064
# 3  1997        843161        612490        502010
# 4  1998       1187320        574827        692095

# %%
# Visualize Data

plt.scatter(data['Year'], data['Winter Cases'])
plt.xlabel('Year')
plt.ylabel('Winter Cases')
plt.title('Years Vs Winter Cases')
plt.show()

# %%
# Divide the data into training and testing sets using train_test_split.Python
# 2. Prepare Data for Model
X = data['Year'].values.reshape(-1, 1) # Reshape for linear regression
y = data['Winter Cases'].values

# 3. Split Data into Training and Testing Sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=30)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((24, 1), (6, 1), (24,), (6,))

# %%
# 4. Create and Train the Model
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# 5. Make Predictions on the Test Set
y_pred = model.predict(X_test)

print(y_pred)
print(y_test)
# Out:
# [1313262.92443797 1639686.51103248 1589467.49771024 1187715.39113239
#  1539248.48438801  936620.32452124]
# [1329077 1811535 1700027 1083007 1655263  991710]

# %%
# 6. Evaluate the Model
mse = mean_squared_error(y_test, y_pred)
print('Mean Squared Error:', mse)
# Out:
# Mean Squared Error: 11577246507.23929

# %%
# 7. Visualize the Model's Predictions
plt.scatter(X_test, y_test, color='black')
plt.plot(X_test, y_pred, color='blue', linewidth=3)
plt.xlabel('Year')
plt.ylabel('winter cases')
plt.title('Linear Regression Model')
plt.show()

# %%
# multiple regression 
# Visualize the data (optional, for simple datasets)
# For complex datasets, consider pair plots or 3D scatter plots

# Create a figure with 1 row and 3 columns (for 3 subplots)
fig, axes = plt.subplots(1, 3, figsize=(12, 4)) # Adjust figsize as needed

# Create scatter plots in each subplot
axes[0].scatter(data['Year'], data['Winter Cases'])
axes[0].set_xlabel('Year')
axes[0].set_ylabel('Winter Cases')
axes[0].set_title('Year vs Winter Cases')

axes[1].scatter(data['Year'], data['Summer Cases'])
axes[1].set_xlabel('Year')
axes[1].set_ylabel('Summer Cases')
axes[1].set_title('Year vs Summer Cases')

axes[2].scatter(data['Year'], data['Autumn Cases'])
axes[2].set_xlabel('Year')
axes[2].set_ylabel('Autumn Cases')
axes[2].set_title('Year vs Autumn Cases')

# Adjust layout (optional)
plt.tight_layout()
# display the figure 
plt.show()

# %%
# Prepare data for model
X = data[['Summer Cases', 'Autumn Cases']]
y = data['Winter Cases']

# %%
# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=30)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((24, 2), (6, 2), (24,), (6,))

# %%
# Create and train the model
model = LinearRegression()
model.fit(X_train, y_train)

# Make predictions on the test set
# Out:
# LinearRegression()

# %%
# prediction
y_pred = model.predict(X_test)

print(y_pred)
print(y_test)
# Out:
# [1251095.23562722 1626918.86992246 1451436.52321864 1289553.26110269
#  1537962.22768976 1097374.32767997]
# 15    1329077
# 28    1811535
# 26    1700027
# 10    1083007
# 24    1655263
# 0      991710
# Name: Winter Cases, dtype: int64

# %%
# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)

# You can visualize the model's predictions in various ways,
# depending on the complexity of the data and the desired insights.
# For simple linear regression, you might plot predicted vs. actual values.
# For more complex models, consider residual plots or feature importance analysis.
# Out:
# Mean Squared Error: 28257879251.670948

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming your data is in a pandas DataFrame named 'df'
# with columns 'X1', 'X2', 'X3', and 'y'

# Pairwise scatter plots
sns.pairplot(data, x_vars=['Summer Cases', 'Autumn Cases'], y_vars='Winter Cases', kind='reg')
plt.show()

# %%
y_train_pred = model.predict(X_train)
y_train_pred.shape
# Out:
# (24,)
